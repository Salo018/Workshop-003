# %%
#Importar librerias necesarias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
import pickle

# %%
#Cargar dataset limpio
df = pd.read_csv('C:/Users/Asus/OneDrive/Desktop/Workshop-003/data/df_clean.csv')
df.head(1)
# Out:
#    Year      Country      GDP  Social_Support  Life_Expectancy  Freedom  \
# 0  2015  Switzerland  1.39651         1.34951          0.94143  0.66557
#
#    Happiness_Score
# 0            7.587

# %% [markdown]
# ### Entrenamiento del modelo

# %%
# Separar features y target
X = df[['GDP', 'Social_Support', 'Life_Expectancy', 'Freedom']]
y = df['Happiness_Score']

print("Shape X:", X.shape)
print("Shape y:", y.shape)
# Out:
# Shape X: (781, 4)
# Shape y: (781,)

# %%
#Separar los datos, 70% para entrenamiento y el 30% para prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=80)

print("Entrenamiento:", X_train.shape)
print("Prueba:", X_test.shape)
# Out:
# Entrenamiento: (546, 4)
# Prueba: (235, 4)

# %%
#Entrenar modelo de regresión lineal
model = LinearRegression()
model.fit(X_train, y_train)
print("Modelo entrenado exitosamente")
# Out:
# Modelo entrenado exitosamente

# %%
#Guardar modelo como .pkl
with open('C:/Users/Asus/OneDrive/Desktop/Workshop-003/models/model.pkl', 'wb') as f:
    pickle.dump(model, f)
print("Modelo guardado en models/model.pkl")
# Out:
# Modelo guardado en models/model.pkl
